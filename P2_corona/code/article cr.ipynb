# %%
import urllib.request
from bs4 import BeautifulSoup
#from urllib import parse


def mg(month):
    #keyword = '+'+parse.quote(key)
    #print(keyword)
    
    if month < 10:
        month ='0'+str(month)
    else:
        month = str(month)
        
    keyls = ['%C4%DA%B7%CE%B3%AA+%BA%F1%B4%EB%B8%E9','%C4%DA%B7%CE%B3%AA+%BE%F0%C5%C3%C6%AE','%C4%DA%B7%CE%B3%AA+%BF%C2%B6%F3%C0%CE','%C4%DA%B7%CE%B3%AA+%BF%F8%B0%DD','%C4%DA%B7%CE%B3%AA+%B7%A3%BC%B1']
    # 코로나 + 비대면 언택트 온라인 랜선 원격
    #month =
    svurl = []
    for kwd in keyls:
        for pn in range(1,1000000):
            list_url = "http://find.mk.co.kr/new/search.php?pageNum="+str(pn)+"&cat=&cat1=&media_eco=&pageSize=10&sub=all&dispFlag=OFF&page=news&s_kwd="+kwd+"&s_page=news&go_page=&ord=1&ord1=1&ord2=0&s_keyword="+kwd+"&period=p_direct&s_i_keyword="+kwd+"&s_author=&y1=2020&m1="+month+"&d1=01&y2=2020&m2="+month+"&d2=31&ord=1&area=ttbd"
            #print(list_url)
            url = urllib.request.Request(list_url)
            print(url)
            try:
                result = urllib.request.urlopen(url).read().decode("cp949")
                soup = BeautifulSoup(result,'html.parser')
                result1 = soup.find_all('span',class_="class_tit")
                artn=result1[0].get_text()
                n=artn.index('건')
                tnum=artn[11:n].replace(',','')
                en = int(int(tnum)/20)+1
                #print(en)
                if pn == en+1:
                    break
                print(artn)
                result2 = soup.find_all('span',class_="art_tit")
                for j in result2:
                    for k in j:
                        #print(k.get("href"))
                        svurl.append(k.get("href"))
            except:
                pass
    print(len(svurl))
    print(len(list(set(svurl))))
    return svurl

#-------

def mg_scrl(month):
    #params=[]
    tmpmg = mg(month)
    params1=[]

    for ulst in list(set(tmpmg)):
        print(ulst)
        #list_url = 
        url = urllib.request.Request(ulst)
        result = urllib.request.urlopen(url).read()#.decode("cp949")
        #print(result)
        soup = BeautifulSoup(result, "html.parser")

        result1 = soup.find_all('div', class_='art_txt')
        #print(result1)
        #result2 = soup.find_all('p', class_="con")

        #params2=[]
        for i in result1:
            params1.append(i.get_text(" ",strip=True)+'\n'+'\n')

        #for i in result2:
        #    params2.append(i.get_text(" ",strip=True))

        #for i,j in zip(params1,params2):
        #    params.append(i + ' ' + j+'\n')
    f = open('c:\\data\\'+'crl'+str(month)+'.txt','w',encoding = "utf-8")
    #print(params1)
    f.writelines(params1)
    f.close()
    #return params1

# %%
mg_scrl(5)
# Out:
# ...
# 뉴스 검색결과 [총 1,025건 중 1 - 20]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 21 - 40]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 41 - 60]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 81 - 100]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 101 - 120]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 121 - 140]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 141 - 160]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 161 - 180]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 181 - 200]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 201 - 220]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 221 - 240]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 241 - 260]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 261 - 280]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 281 - 300]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 301 - 320]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 321 - 340]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 341 - 360]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 361 - 380]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 381 - 400]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 401 - 420]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 421 - 440]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 441 - 460]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 461 - 480]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 481 - 500]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 501 - 520]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 521 - 540]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 541 - 560]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 561 - 580]
#
# ...

# %%
mg(5)
# Out:
# ...
# 뉴스 검색결과 [총 1,025건 중 1 - 20]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 21 - 40]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 41 - 60]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 81 - 100]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 101 - 120]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 121 - 140]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 141 - 160]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 161 - 180]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 181 - 200]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 201 - 220]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 221 - 240]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 241 - 260]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 261 - 280]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 281 - 300]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 301 - 320]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 321 - 340]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 341 - 360]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 361 - 380]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 381 - 400]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 401 - 420]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 421 - 440]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 441 - 460]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 461 - 480]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 481 - 500]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 501 - 520]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 521 - 540]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 541 - 560]
#
# ...
# 뉴스 검색결과 [총 1,025건 중 561 - 580]
#
# ...

# %%
ts
# Out:
# ['https://www.mk.co.kr/news/economy/view/2020/01/93366/',
#  'https://www.mk.co.kr/news/economy/view/2020/01/86962/',
#  'https://www.mk.co.kr/news/stock/view/2020/01/94081/',
#  'https://www.mk.co.kr/news/economy/view/2020/01/93366/',
#  'https://www.mk.co.kr/news/world/view/2020/01/103336/',
#  'https://www.mk.co.kr/news/world/view/2020/01/103328/',
#  'https://www.mk.co.kr/news/world/view/2020/01/103202/',
#  'https://www.mk.co.kr/news/world/view/2020/01/103192/',
#  'https://www.mk.co.kr/news/society/view/2020/01/103065/',
#  'https://www.mk.co.kr/news/home/view/2020/01/102891/',
#  'https://www.mk.co.kr/news/stock/view/2020/01/102670/',
#  'https://www.mk.co.kr/news/stock/view/2020/01/102666/',
#  'https://www.mk.co.kr/news/world/view/2020/01/102483/',
#  'https://www.mk.co.kr/news/society/view/2020/01/102376/',
#  'https://www.mk.co.kr/news/politics/view/2020/01/101986/',
#  'https://www.mk.co.kr/news/society/view/2020/01/101953/',
# ...

# %%
def mg_scrl():
    params=[]
    
    for ulst in 리스트:
        #list_url = 
        url = urllib.request.Request(ulst)
        result = urllib.request.urlopen(url).read().decode("utf-8")
        soup = BeautifulSoup(result, "html.parser")

        result1 = soup.find_all('div', class_='art_txt')
        #result2 = soup.find_all('p', class_="con")

        params1=[]
        #params2=[]
        for i in result1:
            params1.append(i.get_text(" ",strip=True))

        #for i in result2:
        #    params2.append(i.get_text(" ",strip=True))

        #for i,j in zip(params1,params2):
        #    params.append(i + ' ' + j+'\n')
    f = open('c:\\data\\ladybug.txt','w',encoding = "UTF-8")
    f.writelines(params1)
    f.close()
    return params1
    

mg_scrl()

# %%
err=b"""½ÅÁ¾ÄÚ·Î³ª °¨¿°ÀÚ °ü·Ã ºê¸®ÇÎÇÏ´Â Á¤¼ø±Õ ±¸Ã»Àå ¢º ¿©±â¸¦ ´©¸£½Ã¸é Å©°Ô º¸½Ç ¼ö ÀÖ½À´Ï´Ù ¼Ò¼È³×Æ®¿öÅ©¼­ºñ½º(SNS)·Î °ÅÁþ '½ÅÁ¾ÄÚ·Î³ª È®ÁøÀÚ ¹æ¹®Àå¼Ò' ¸Þ½ÃÁö°¡ È®»êÇÏÀÚ Áö¹æÀÚÄ¡´ÜÃ¼°¡ °­°æ ´ëÀÀ¿¡ ³ª¼¹´Ù Á¤¼ø±Õ ¼­¿ï °­³²±¸Ã»ÀåÀº 30ÀÏ ¼­¿ï½ÃÃ»¿¡¼­ ºê¸®ÇÎÀ» ¿­¾î "°ü³» Æ¯Á¤ ¾÷¼ÒÀÇ »óÈ£°¡ ´ã±ä '°¡Â¥´º½º'°¡ ¿Â¶óÀÎ¿¡¼­ ´ë·® À¯Æ÷µÈ´Ù"¸ç "ÀÛ¼ºÀÚ¿Í À¯Æ÷ÀÚ¸¦ ¼­¿ï °­³²°æÂû¼­¿¡ ¼ö»ç ÀÇ·ÚÇß´Ù"°í ¹àÇû´Ù. ±¸´Â "°¡Â¥ ´º½º·Î ÀÎÇØ ÇÊ¿ä ÀÌ»óÀÇ »çÈ¸ ºÒ¾È°¨ÀÌ Á¶¼ºµÇ°í ¼±ÀÇÀÇ ÇÇÇØÀÚ³ª ¾÷¼Ò°¡ ¹ß»ýÇÏ´Â °ÍÀ» Â÷´ÜÇÏ°íÀÚ ÇÑ´Ù"°í ¼³¸íÇß´Ù. ½ÅÁ¾ ÄÚ·Î³ª¹ÙÀÌ·¯½º °¨¿°ÁõÀÎ '¿ìÇÑ Æó·Å'ÀÇ ±¹³» 3¹øÂ° È®Áø È¯ÀÚÀÎ Áß±¹ °ÅÁÖ 54¼¼ ÇÑ±¹ÀÎ ³²¼ºÀº ÀÔ±¹ ÈÄ °­³²±¸ ÀÏ´ë¸¦ µ¹¾Æ´Ù³æ´ø °ÍÀ¸·Î ¾Ë·ÁÁ® ÀÖ´Ù. ±¸¿¡ µû¸£¸é È®ÁøÀÚ°¡ ½ÇÁ¦·Î ¹æ¹®ÇÏÁö ¾Ê¾Ò´Âµ¥µµ °¡Â¥´º½º¿¡ ÀÌ¸§ÀÌ µîÀåÇØ ÇÇÇØ¸¦ º¸´Â ¾÷¼Ò´Â ÀÓÇÇ¸®¾óÆÓ¸®½º¼­¿ï È£ÅÚ, ±×·£µå¼ºÇü¿Ü°ú, ½Å³íÇö ´ÙÀÌ¼Ò µîÀÌ´Ù. ±¸´Â "3¹øÂ° È®ÁøÀÚ°¡ ¸¸³­ Á¢ÃËÀÚµéÀ» ¸ÅÀÏ ¸ð´ÏÅÍ¸µÇØ ¿À´Ã±îÁö ÀÌ»óÀÌ ¾ø´Â °ÍÀ» È®ÀÎÇß´Ù"¸ç "°ü³» 14°³ ¹æ¹® ¾÷¼Òµµ ¸ðµÎ ¼Òµ¶ÇØ °¨¿° À§Çè¼ºÀÌ ¾ø´Ù. ÄÚ·Î³ª¹ÙÀÌ·¯½º´Â ÀÏ¹ÝÀûÀ¸·Î 24¡­48½Ã°£ ³» ÀÚ¿¬ »ç¸êÇÑ´Ù"°í °­Á¶Çß´Ù. Á¤ ±¸Ã»ÀåÀº "È®ÁøÀÚ°¡ ¹æ¹®ÇÑ ¾÷¼Ò¶óµµ ÀÏ´Ü ¹æ¿ª ¼Òµ¶ÀÌ ½Ç½ÃµÈ °÷Àº Ãß°¡ °¨¿° À§ÇèÀÌ ÀüÇô ¾øÀ¸´Ï ¾È½ÉÇÏ°í ¹æ¹®ÇØµµ µÈ´Ù"¸é¼­ "°¡Â¥ ´º½º¿¡ ÇöÈ¤µÅ ºÒ¾ÈÇØÇÏ°Å³ª ¹æ¹®À» ±âÇÇÇÒ ÇÊ¿ä°¡ ¾ø´Ù"°í Àß¶ó ¸»Çß´Ù. [¿¬ÇÕ´º½º] Copyrights ¨Ï ¿¬ÇÕ´º½º. ¹«´Ü ÀüÀç ¹× Àç¹èÆ÷±ÝÁö window.jQuery || document.write("<script src='//common.mk.co.kr/common/include/mklib/jquery.js'>")"""
# Out:
#   File "<ipython-input-76-74c2236f86f1>", line 1
# ...

# %%
err.decode('utf-8')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-d3da6a06b7aa> in <module>
# ----> 1 err.decode('utf-8')
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
import urllib.request
from bs4 import BeautifulSoup

def ebs_scroll():
    list_url = "https://www.mk.co.kr/news/society/view/2020/01/103065/"
    url = urllib.request.Request(list_url)
    result = urllib.request.urlopen(url).read().decode("cp949")
    soup = BeautifulSoup(result, "html.parser")
    return soup
print(ebs_scroll() )
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-81-802ea0a81ad6> in <module>
#       8     soup = BeautifulSoup(result, "html.parser")
#       9     return soup
# ---> 10 print(ebs_scroll() )
#
# <ipython-input-81-802ea0a81ad6> in ebs_scroll()
#       5     list_url = "https://www.mk.co.kr/news/society/view/2020/01/103065/"
#       6     url = urllib.request.Request(list_url)
# ----> 7     result = urllib.request.urlopen(url).read().decode("cp949")
#       8     soup = BeautifulSoup(result, "html.parser")
#       9     return soup
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xbc in position 1538: illegal multibyte sequence

# %%
from konlpy.tag import Kkma
from konlpy.utils import pprint

kkma = Kkma()

print(sorted(kkma.nouns(news)))
# >>> ['오류', '실행', '오늘', '여기', '안녕']
# Out:
# ['-0.53', '-0.55', '-1.5', '-1.6', '-1.89', '-10.0', '-11.69', '-12.5', '-1214', '-19.3', '-2.52', '-2.70', '-23.11', '-2910', '-3.4', '-3.7', '-3.8', '-3.81', '-3.96', '-4.04', '-4.18', '-4.35', '-4.55', '-4891', '-5.78', '-5.80', '-65', '-7.89', '-77', '-81', '-9.35', '-9.76', '-9898', '0', '0.1', '0.2', '0.4', '0.4㎛', '0.6', '0.6㎛', '0.8', '0.8배', '0.9', '00', '000120', '000660', '001', '001120', '001의', '002720', '003530', '004380', '004540', '005960', '007460', '008560', '009730', '00병원', '011000', '011780', '012510', '012690', '016590', '017650', '018290', '018620', '019570', '019660', '020760', '026890', '029780', '032580', '034120', '034220', '038070', '039200', '043710', '053590', '058220', '058530', '059090', '0618', '064960', '065620', '067280', '068330', '072520', '079160', '083550', '084650', '085620', '089030', '090460', '096770', '0시', '0시50분', '1', '1,000', '1,000원', '1,027', '1,027억원', '1,035.1', '1,182', '1,182억원', '1,215', '1,215원', '1,224', '1,224억원', '1,295', '1,
# ...

# %%
from konlpy.tag import Okt
from collections import Counter
import re
from wordcloud import WordCloud, STOPWORDS  

f = open("c:\\data\\crl1.txt",'r',encoding = 'utf-8')
news = f.read()

okt=Okt()
noun = okt.nouns(news)
for i,v in enumerate(noun):
    if len(v)<2:
        noun.pop(i)
count = Counter(noun)

noun_list = count.most_common(1000)
for v in noun_list:
    print(v)
# Out:
# ('우한', 760)
# ('중국', 717)
# ('폐렴', 477)
# ('마스크', 471)
# ('신종', 440)
# ('코로나바이러스', 300)
# ('확산', 286)
# ('환자', 241)
# ('온라인', 202)
# ('코로나', 192)
# ('연합뉴스', 191)
# ('관련', 189)
# ('감염', 174)
# ('중국인', 166)
# ('금지', 161)
# ('진자', 157)
# ('바이러스', 149)
# ('지역', 143)
# ('발생', 139)
# ('사람', 138)
# ('정부', 134)
# ('대한', 132)
# ('배포', 128)
# ('홍콩', 125)
# ('상황', 122)
# ('우려', 121)
# ('및', 120)
# ('크게', 118)
# ('대해', 117)
# ('병원', 117)
# ('무단', 116)
# ('사태', 116)
# ('지난', 115)
# ('위해', 114)
# ('매출', 113)
# ('여기', 109)
# ('감염증', 105)
# ('한국', 103)
# ('대비', 101)
# ('가운데', 98)
# ('판매', 98)
# ('기록', 96)
# ('사스', 95)
# ('일부', 94)
# ('의료', 94)
# ('국내', 94)
# ('춘제', 93)
# ('기간', 93)
# ('현재', 92)
# ('동사', 92)
# ('당국', 91)
# ('통해', 90)
# ('정보', 90)
# ('확인', 88)
# ('상승', 88)
# ('취소', 87)
# ('조치', 87)
# ('베이징', 86)
# ('경우', 85)
# ('방문', 84)
# ('말', 83)
# ('지난해', 82)
# ('대책', 81)
# ('것', 81)
# ('대응', 80)
# ('발표', 79)
# ('입국', 79)
# ('사실', 77)
# ('시장', 76)
# ('연휴', 74)
# ('증가', 73)
# ('중단', 72)
# ...

# %%
from konlpy.tag import Okt
from collections import Counter
import re
from wordcloud import WordCloud, STOPWORDS  

f = open("c:\\data\\crl5.txt",'r',encoding = 'utf-8')
news = f.read()#.split(' ')
stwd2 = ['코로나','중국','신종','확산','연합뉴스','금지','관련','코로나바이러스','지역','배포','위해','무단','진자','한국','통해','상황','지난','사태','예정','대한','대해','기자','우한','관계자','경우','대비','연기','크게','직원','지원','증가','조치','사람','여기','설명','일부','진행','최근','우려','바이러스','서울','대응','이후','때문','발생','가운데','상승','대구','이번','현재','당국','기간','방문','취소','결정','신천지','제공','전국','중단','대상','모든','지난해','뉴스','계획','국민','발표','대책','매일경제','시간','제품','중국인','확대','사진','올해','영향','이용','다른','기준','시작','오후','해당','전자','테마','우리','이상','미국','전망','대표','분석','하락','모두','라며','지난달','최대','오전','추가','피해','롯데','면서','포함','국가','실적','홈페이지','가능성','주요','세계','홍콩','급증','사실','업무','지속','문제','소비','소식','조사','다음','확진','감소','권고','상품','가장','한편','직접','건강','경북','갤럭시','시설','급등','예상','마련','결과','상태','규모','모습','검사','경기','마감','현지','방침','위기','사용','기관','의견','내용','긴급','시행','글로벌','앞서','주민','시민','방지','강조','기존','방안','근무','위원회','활용','일본','민주당','자가','현장','기사','역시','본부','물량','여파','전체','일정','삼성','경찰','공개','하루','그룹','이익','성장','전날','행위','기술','정도','집중','활동','개인','의원','중앙','중이','제한','다만','팩트','자제','단계','검토','장관','확보','지수','동사','해외','준비','안정','감염병','대체','방식','거나','비상','출시','휴업','적극','최고','질병','매수','메르스','참여','가족','교민','생각','최소','의사','지적','통제','중심','주일','비롯','자체','착용','이유','아이','여부','처음','교수','실시','항공','특별','실제','동안','입장','지금','상세','보고','분위기','리원량','신규','고려','각각','수준','효과','증시','인력','판정','통합','외부','사례','계속','특종','책임','사망자','추진','측은','전환','만큼','이슈','폐렴','또한','어려움','요청','제목','비판','공포','단체','현상','요구','방법','점검','연장','여러','대부분','유지','매도','조정','통한','전염병','정책','차단','명의','평가','증상','카카오','다시','주말','판단','트위터','의심','부품','주장','경기도','신도','한국인','생활','프로그램','참석','후베이성','근거','강화','우선','신고','대신','과정','대감','부산','수급','매일','수가','회장','자신','자금','공식','관심','전문가','전일','강세','신청','자료','파악','임시','위험','하나','사망','노력','작년','주간','일반','전달','폐쇄','지지','장기','평균','중인','보호','당부','당시','점포','독일','주석','안내','사스','히스토리','제외','학부모','협력','집회','반면','목표','무료','개선','브랜드','전파','판매량','시기','지정','여명','위원장','유럽','사이','협의','포인트','휴가','차질','가량','개최','달라','관계','논의','수도','현대','소재','수용','더욱','주목','기억','설치','네이버','허용','기도','접속','당사','가동','대규모','주소','예비','분야','개월','도입','타격','목소리','지인','가지','발병','태국','문의','전문','재난','대통령','출입','부담','건물','처리','계약','봉쇄','이하','적용','본사','불안','체크','별로','보유','여성','커뮤니티','내부','장비','자동차','공지','극복','금리','에탄올','수사','바로','접수','신호','기부','인하','비교','평소','우체국','개요','아이폰','전면','기반','연휴','인기','가짜','동기','불안감','비용','주의','필요','안드로이드','발열','종합','사건','경보','마음','도시','비중','당분간','심각','재개','예약','최대한','화웨이','손실','오늘','지연','기능','유포','국제','협회','인원','수혜','다수','해결','총리','걱정','본격','언급','포스','감독','집계','대변인','각종','지침','향후','외출','아파트','작업','베트남','제작','공시','체계','제보','진천','기숙사','게시','호소','인천','일자리','상공','위축','차원','변화','단독','허위','별도','아시아','경고','코리아','베이징','단지','구성','급락','체류','기대','증후군','플립','변경','품귀','보고서','상장','반영','제도','당초','일시','경영','매점매석','솔루션','자산','축소','이야기','공적','수입','모임','자리','발언','특징','리스트','갤러리아','업자','최초','보이','잠정','지점','형태','학사','동시','도움','사전','소속','체제','약세','상승세','핵심','절차','논란','여의도순복음교회','공인','판지','이전','정기','정상','선택','조처','이름','정제','상한','제지','격상','단속','부총리','주재','집단','지방','지도','주주','자유','중증','이탈리아','필수','인근','매우','편성','경로','일수','인사','공동','보기','반응','서울시','여러분','발원','소개','제주','의무','손님','연일','로부터','보건소','지급','증권사','적자','대폭','활성화','차례','처벌','일주일','대처','촉구','연락','달리','초기','거리','오히려','카드','소상','대출','유출','먼저','제약','공항','청사','의미','출근','지사','주로','강제','품목','손소독제','거주','투입','오픈','신문','악화','출처','자녀','동선','규제','출장','물건','목적','회복','부문','사항','추세','자율','수량','이용자','대전','규정','부분','품절','재고','할인','위치','전역','전반','도착','친구','충북','추정','춘제','부진','구축','재정','달러','누적','상하이','원내대표','사랑','성과','서도','사고','주변','키트','이틀','인민','시진핑','사재기','차량','수치','취재','제기','체험','협조','과거','메시지','조기','혐의','표현','가치','포장','외교부','투자자','더블','시즌','내달','시도','고민','속도','절반','비율','시점','중동','식당','이내','누리꾼','기본','번가','특정','새벽','체결','무역','본점','구입','자영','후베이','역할','우한시','조직','일단','코스닥','라면','아이스크림','충격','구체','교인','지자체','이외','홍보','영국','졸업식','청원','진출','취하','애플','적발','근로자','방향','차지','기침','포스트','회원','한시','반대','기회','광주','해소','위반','바이오','중소','반등','비례대표','긍정','거의','명품','상가','음성','싱가포르','부족','체온','인수','경쟁','분양','천추스','해도','부정','검색','흐름','사장','취약','유행','전통','인식','순이익','메이트','약속','사옥','이낙연','상대','예측','배당','동영상','운동','진정','경찰청','분류','지시','고용','문재인','다중','최선','동참','등록','제시','민간','질문','여론','연구소']

for i in STOPWORDS:
    news = re.sub(i,'',news)
for i in stwd2:
    news = re.sub(i,'',news)

okt=Okt()
noun = okt.nouns(news)
for i,v in enumerate(noun):
    if len(v)<2:
        noun[i]=''
        
count = Counter(noun)

noun_list = count.most_common(10000)
for v in noun_list:
    print(v)
# Out:
# ('', 246991)
# ('온라인', 4777)
# ('기업', 3421)
# ('사업', 2700)
# ('등교', 2680)
# ('서비스', 2596)
# ('시장', 2521)
# ('학생', 2518)
# ('투자', 2515)
# ('매출', 2477)
# ('종목', 2376)
# ('정부', 2361)
# ('학교', 2180)
# ('수업', 2138)
# ('경제', 2043)
# ('국내', 1842)
# ('산업', 1832)
# ('방역', 1792)
# ('사회', 1700)
# ('감염증', 1634)
# ('교육', 1576)
# ('영업', 1563)
# ('기록', 1497)
# ('운영', 1493)
# ('비대', 1459)
# ('거래', 1455)
# ('센터', 1454)
# ('디지털', 1427)
# ('정보', 1417)
# ('감염', 1323)
# ('개발', 1311)
# ('고객', 1291)
# ('판매', 1287)
# ('업체', 1259)
# ('모바일', 1125)
# ('게임', 1084)
# ('의료', 1068)
# ('행사', 1067)
# ('금융', 1057)
# ('마스크', 1041)
# ('학년', 1021)
# ('관리', 1014)
# ('시스템', 960)
# ('업종', 907)
# ('언택트', 880)
# ('은행', 875)
# ('수요', 870)
# ('두기', 866)
# ('업계', 864)
# ('회의', 860)
# ('플랫폼', 853)
# ('주가', 846)
# ('치료', 843)
# ('영상', 817)
# ('수출', 809)
# ('회사', 784)
# ('시험', 772)
# ('교육청', 768)
# ('시대', 751)
# ('증권', 747)
# ('데이터', 746)
# ('진단', 745)
# ('생산', 718)
# ('전략', 709)
# ('콘텐츠', 701)
# ('혁신', 688)
# ('뉴딜', 684)
# ...

# %%
import urllib.request
from bs4 import BeautifulSoup
#from urllib import parse


def mg1(month):
    #keyword = '+'+parse.quote(key)
    #print(keyword)
    
    if month < 10:
        month ='0'+str(month)
    else:
        month = str(month)
        
    keyls = ['%BA%F1%B4%EB%B8%E9','%BE%F0%C5%C3%C6%AE','%BF%C2%B6%F3%C0%CE','%BF%F8%B0%DD','%B7%A3%BC%B1']
    # 코로나 + 비대면 언택트 온라인 랜선 원격
    #month =
    svurl = []
    for kwd in keyls:
        for pn in range(1,1000000):
            list_url = "http://find.mk.co.kr/new/search.php?pageNum="+str(pn)+"&cat=&cat1=&media_eco=&pageSize=10&sub=all&dispFlag=OFF&page=news&s_kwd="+kwd+"&s_page=news&go_page=&ord=1&ord1=1&ord2=0&s_keyword="+kwd+"&period=p_direct&s_i_keyword="+kwd+"&s_author=&y1=2019&m1="+month+"&d1=01&y2=2019&m2="+month+"&d2=31&ord=1&area=ttbd"
            #print(list_url)
            url = urllib.request.Request(list_url)
            print(url)
            try:
                result = urllib.request.urlopen(url).read().decode("cp949")
                soup = BeautifulSoup(result,'html.parser')
                result1 = soup.find_all('span',class_="class_tit")
                artn=result1[0].get_text()
                n=artn.index('건')
                tnum=artn[11:n].replace(',','')
                en = int(int(tnum)/20)+1
                #print(en)
                if pn == en+1:
                    break
                print(artn)
                result2 = soup.find_all('span',class_="art_tit")
                for j in result2:
                    for k in j:
                        #print(k.get("href"))
                        svurl.append(k.get("href"))
            except:
                pass
    print(len(svurl))
    print(len(list(set(svurl))))
    return svurl

#-------

def mg_scrl1(month):
    #params=[]
    tmpmg = mg1(month)
    params1=[]

    for ulst in list(set(tmpmg)):
        print(ulst)
        #list_url = 
        url = urllib.request.Request(ulst)
        result = urllib.request.urlopen(url).read()#.decode("cp949")
        #print(result)
        soup = BeautifulSoup(result, "html.parser")

        result1 = soup.find_all('div', class_='art_txt')
        #print(result1)
        #result2 = soup.find_all('p', class_="con")

        #params2=[]
        for i in result1:
            params1.append(i.get_text(" ",strip=True)+'\n'+'\n')

        #for i in result2:
        #    params2.append(i.get_text(" ",strip=True))

        #for i,j in zip(params1,params2):
        #    params.append(i + ' ' + j+'\n')
    f = open('c:\\data\\'+'Ncrl'+str(month)+'.txt','w',encoding = "utf-8")
    #print(params1)
    f.writelines(params1)
    f.close()
    #return params1

# %%
for i in range(1,13):
    mg_scrl1(i)
# Out:
# ...
# 뉴스 검색결과 [총 80건 중 1 - 20]
#
# ...
# 뉴스 검색결과 [총 80건 중 21 - 40]
#
# ...
# 뉴스 검색결과 [총 80건 중 41 - 60]
#
# ...
# 뉴스 검색결과 [총 80건 중 61 - 80]
#
# ...
# 뉴스 검색결과 [총 80건 중 81 - 100]
#
# ...
# 뉴스 검색결과 [총 0건중 1 - 20]
#
# ...
# 뉴스 검색결과 [총 2,248건 중 1 - 20]
#
# ...
# 뉴스 검색결과 [총 2,248건 중 21 - 40]
#
# ...
# 뉴스 검색결과 [총 2,248건 중 61 - 80]
#
# ...
# 뉴스 검색결과 [총 2,248건 중 81 - 100]
#
# ...
# 뉴스 검색결과 [총 2,248건 중 101 - 120]
#
# ...
# 뉴스 검색결과 [총 2,248건 중 121 - 140]
#
# ...
# 뉴스 검색결과 [총 2,248건 중 141 - 160]
#
# ...
# 뉴스 검색결과 [총 2,248건 중 161 - 180]
#
# ...
# 뉴스 검색결과 [총 2,248건 중 181 - 200]
#
# ...
# 뉴스 검색결과 [총 2,248건 중 201 - 220]
#
# ...
# 뉴스 검색결과 [총 2,248건 중 221 - 240]
#
# ...
# 뉴스 검색결과 [총 2,248건 중 241 - 260]
#
# ...
# 뉴스 검색결과 [총 2,248건 중 261 - 280]
#
# ...
# 뉴스 검색결과 [총 2,248건 중 281 - 300]
#
# ...
# 뉴스 검색결과 [총 2,248건 중 301 - 320]
#
# ...
# 뉴스 검색결과 [총 2,248건 중 321 - 340]
#
# ...
# 뉴스 검색결과 [총 2,248건 중 341 - 360]
#
# ...
# 뉴스 검색결과 [총 2,248건 중 361 - 380]
#
# ...
# 뉴스 검색결과 [총 2,248건 중 381 - 400]
#
# ...
# 뉴스 검색결과 [총 2,248건 중 401 - 420]
#
# ...
# 뉴스 검색결과 [총 2,248건 중 421 - 440]
#
# ...
# 뉴스 검색결과 [총 2,248건 중 461 - 480]
#
# ...
# 뉴스 검색결과 [총 2,248건 중 481 - 500]
#
# ...
